# %%
from qd_transform import SequenceImageTransform
import cv2 as cv
import numpy as np
from torchvision import transforms
from PIL import Image

# %%
transform = transforms.Compose([
            transforms.Resize(224),
            SequenceImageTransform(to_size=(8, 8, 3), fixed_length=196),
            transforms.ToTensor(),
        ])

# %%
img = cv.imread('./test0.JPEG') 
img = Image.fromarray(img) 
img = transform(img)
# Out:
# seq_patch length: 196

# %%
img.shape
# Out:
# torch.Size([3, 8, 1568])
